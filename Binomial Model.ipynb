# %%
import pandas
import numpy

# %%
#load datasets
am_df = pandas.read_csv("data/american_stock.csv")
eu_df = pandas.read_csv("data/european_index.csv")

# %%
am_df.head()
# Out:
#     secid      date              symbol  symbol_flag    exdate   last_date  \
# 0  101594  20150102  AAPL 150102C100000            1  20150102  20150102.0
# 1  101594  20150102  AAPL 150102C101000            1  20150102  20150102.0
# 2  101594  20150102  AAPL 150102C102000            1  20150102  20150102.0
# 3  101594  20150102  AAPL 150102C103000            1  20150102  20150102.0
# 4  101594  20150102  AAPL 150102C104000            1  20150102  20150102.0
#
#   cp_flag  strike_price  best_bid  best_offer  ...   sic  index_flag  \
# 0       C        100000      9.20        9.35  ...  3571           0
# 1       C        101000      8.20        8.40  ...  3571           0
# 2       C        102000      7.25        7.35  ...  3571           0
# 3       C        103000      6.20        6.40  ...  3571           0
# 4       C        104000      5.25        5.35  ...  3571           0
#
#    exchange_d  class  issue_type  industry_group     issuer  div_convention  \
# ...

# %%
eu_df.head
# Out:
# <bound method NDFrame.head of            secid      date                symbol  symbol_flag    exdate  \
# 0         102480  20150102    NDX 150109C3100000            1  20150109
# 1         102480  20150102    NDX 150109C3125000            1  20150109
# 2         102480  20150102    NDX 150109C3150000            1  20150109
# 3         102480  20150102    NDX 150109C3175000            1  20150109
# 4         102480  20150102    NDX 150109C3200000            1  20150109
# ...          ...       ...                   ...          ...       ...
# 12242381  102480  20211231  NDXP 220225P21100000            1  20220225
# 12242382  102480  20211231  NDXP 220225P21200000            1  20220225
# 12242383  102480  20211231  NDXP 220225P21300000            1  20220225
# 12242384  102480  20211231  NDXP 220225P21400000            1  20220225
# 12242385  102480  20211231  NDXP 220225P21500000            1  20220225
#
# ...
